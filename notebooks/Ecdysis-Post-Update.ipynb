# %%
from psycopg2 import DatabaseError
from psycopg2.extras import DictCursor

from idb.postgres_backend.db import PostgresDB, RecordSet

db = PostgresDB()

db.execute("BEGIN")

updatedRecord = {}

updatedRecord.update({'0': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=133','archive 0': 'https://ecdysis.org/content/dwca/ANSP-ENT_DwC-A.zip'})
updatedRecord.update({'1': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=102','archive 1': 'https://ecdysis.org/content/dwca/BROW-BCIC_DwC-A.zip'})
updatedRecord.update({'2': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=55','archive 2': 'https://ecdysis.org/content/dwca/CSEB-CSEB_DwC-A.zip'})
updatedRecord.update({'3': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=111','archive 3': 'https://ecdysis.org/content/dwca/CU-CUAC_DwC-A.zip'})
updatedRecord.update({'4': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=105','archive 4': 'https://ecdysis.org/content/dwca/DBG-DBGA_DwC-A.zip'})
updatedRecord.update({'5': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=132','archive 5': 'https://ecdysis.org/content/dwca/DMNS-Arac_DwC-A.zip'})
updatedRecord.update({'6': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=149','archive 6': 'https://ecdysis.org/content/dwca/DMNS-Ento_DwC-A.zip'})
updatedRecord.update({'7': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=63','archive 7': 'https://ecdysis.org/content/dwca/NAU-NAUFEC_DwC-A.zip'})
updatedRecord.update({'8': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=118','archive 8': 'https://ecdysis.org/content/dwca/LCDI-LERC_DwC-A.zip'})
updatedRecord.update({'9': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=80','archive 9': 'https://ecdysis.org/content/dwca/TTU-TTU-Z_DwC-A.zip'})
updatedRecord.update({'10': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=126','archive 10': 'https://ecdysis.org/content/dwca/UCD-BMEC_DwC-A.zip'})
updatedRecord.update({'11': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=95','archive 11': 'https://ecdysis.org/content/dwca/SDNHM-SDMC_DwC-A.zip'})
updatedRecord.update({'12': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=119','archive 12': 'https://ecdysis.org/content/dwca/SDSU-TAC_DwC-A.zip'})
updatedRecord.update({'13': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=128','archive 13': 'https://ecdysis.org/content/dwca/MSU-MSUC_DwC-A.zip'})
updatedRecord.update({'14': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=106','archive 14': 'https://ecdysis.org/content/dwca/DCH-DCEC_DwC-A.zip'})
updatedRecord.update({'15': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=123','archive 15': 'https://ecdysis.org/content/dwca/USNM-USNMENT_DwC-A.zip'})
updatedRecord.update({'16': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=100','archive 16': 'https://ecdysis.org/content/dwca/GMNH-UGCA_DwC-A.zip'})
updatedRecord.update({'17': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=107','archive 17': 'https://ecdysis.org/content/dwca/UHIM-UHIM_DwC-A.zip'})
updatedRecord.update({'18': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=110','archive 18': 'https://ecdysis.org/content/dwca/UVM-VTZT_DwC-A.zip'})
updatedRecord.update({'19': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=98','archive 19': 'https://ecdysis.org/content/dwca/VPI-VTEC_DwC-A.zip'})
updatedRecord.update({'20': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=112','archive 20': 'https://ecdysis.org/content/dwca/WWU-WWUC_DwC-A.zip'})
updatedRecord.update({'21': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=150','archive 21': 'https://ecdysis.org/content/dwca/UI-WFBM_DwC-A.zip'})



nuuid = []

nuuid.insert(0, 'e73fedf0-90ee-4c6d-88dd-49399878fc54')
nuuid.insert(0, 'f4666aa7-93f0-41f7-83c2-497af7a06887')
nuuid.insert(0, '6acaebd6-e8d2-454a-8f50-e7a6734b8c79')
nuuid.insert(0, '6075f4b7-4242-4886-be7d-391614fffe41')
nuuid.insert(0, '0395f3c4-0277-43b6-a36d-e07720588790')
nuuid.insert(0, '5aac25d2-bcfb-4084-a700-584311ea539d')
nuuid.insert(0, '55b17f44-8c6b-4dc5-a31d-d9955b425790')
nuuid.insert(0, 'f8d0dae7-8927-4f5f-9538-ecddce2e614f')
nuuid.insert(0, '4aecf17c-154a-42fb-a3c0-f5e621c791e6')
nuuid.insert(0, '5e893602-84ca-4c8c-bac1-99111c777582')
nuuid.insert(0, '3c919328-94fd-4657-b81d-21f4707253ed')
nuuid.insert(0, 'e48bb88f-9594-461e-8230-522a3a5572fe')
nuuid.insert(0, '00df4fe2-0025-45ec-814a-36777155e077')
nuuid.insert(0, '87017793-00dc-4f5d-b95b-09e7d17327cc')
nuuid.insert(0, '7ed2ce52-26e5-4847-9563-955ae3e97455')
nuuid.insert(0, 'abb0a03c-4dcb-4f6f-a31d-55268f63d44c')
nuuid.insert(0, '879d475f-4b76-4d18-8cf6-a7e5a6d44926')
nuuid.insert(0, 'cf42855e-a54a-4488-a79e-beac086ba1d4')
nuuid.insert(0, '96588aed-3b7a-4179-b92b-2159427f4fcb')
nuuid.insert(0, '4f436daa-01d5-4be6-b5c3-fdd255677536')
nuuid.insert(0, '34cad268-8226-4280-b637-dde38c82a29e')
nuuid.insert(0, 'b985f284-eac5-4efe-8a7c-c726cdf7cf33')

for i in range(len(nuuid)):
    rssql = "update recordsets set ingest = false where uuid = '{0}'".format(nuuid[i])
    print(rssql)
    db.execute(rssql);
    issql = "update recordsets set ingest = true where file_link = '{0}'".format(updatedRecord['archive {0}'.format(i)])
    print(issql)
    db.execute(issql);

db.commit()
# Out:
# update recordsets set ingest = false where uuid = 'b985f284-eac5-4efe-8a7c-c726cdf7cf33'
# update recordsets set ingest = true where file_link = 'https://ecdysis.org/content/dwca/ANSP-ENT_DwC-A.zip'
# update recordsets set ingest = false where uuid = '34cad268-8226-4280-b637-dde38c82a29e'
# update recordsets set ingest = true where file_link = 'https://ecdysis.org/content/dwca/BROW-BCIC_DwC-A.zip'
# update recordsets set ingest = false where uuid = '4f436daa-01d5-4be6-b5c3-fdd255677536'
# update recordsets set ingest = true where file_link = 'https://ecdysis.org/content/dwca/CSEB-CSEB_DwC-A.zip'
# update recordsets set ingest = false where uuid = '96588aed-3b7a-4179-b92b-2159427f4fcb'
# update recordsets set ingest = true where file_link = 'https://ecdysis.org/content/dwca/CU-CUAC_DwC-A.zip'
# update recordsets set ingest = false where uuid = 'cf42855e-a54a-4488-a79e-beac086ba1d4'
# ...
