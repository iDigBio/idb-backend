# %%
from psycopg2 import DatabaseError
from psycopg2.extras import DictCursor

from idb.postgres_backend.db import PostgresDB, RecordSet

db = PostgresDB()

# %%
db.execute("BEGIN")

nuuid = 'e73fedf0-90ee-4c6d-88dd-49399878fc54'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=133','archive': 'https://ecdysis.org/content/dwca/ANSP-ENT_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = 'f4666aa7-93f0-41f7-83c2-497af7a06887'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=102','archive': 'https://ecdysis.org/content/dwca/BROW-BCIC_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '6acaebd6-e8d2-454a-8f50-e7a6734b8c79'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=55','archive': 'https://ecdysis.org/content/dwca/CSEB-CSEB_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '6075f4b7-4242-4886-be7d-391614fffe41'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=111','archive': 'https://ecdysis.org/content/dwca/CU-CUAC_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '0395f3c4-0277-43b6-a36d-e07720588790'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=105','archive': 'https://ecdysis.org/content/dwca/DBG-DBGA_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '5aac25d2-bcfb-4084-a700-584311ea539d'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=132','archive': 'https://ecdysis.org/content/dwca/DMNS-Arac_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '55b17f44-8c6b-4dc5-a31d-d9955b425790'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=149','archive': 'https://ecdysis.org/content/dwca/DMNS-Ento_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = 'f8d0dae7-8927-4f5f-9538-ecddce2e614f'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=63','archive': 'https://ecdysis.org/content/dwca/NAU-NAUFEC_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '4aecf17c-154a-42fb-a3c0-f5e621c791e6'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=118','archive': 'https://ecdysis.org/content/dwca/LCDI-LERC_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '5e893602-84ca-4c8c-bac1-99111c777582'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=80','archive': 'https://ecdysis.org/content/dwca/TTU-TTU-Z_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '3c919328-94fd-4657-b81d-21f4707253ed'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=126','archive': 'https://ecdysis.org/content/dwca/UCD-BMEC_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = 'e48bb88f-9594-461e-8230-522a3a5572fe'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=95','archive': 'https://ecdysis.org/content/dwca/SDNHM-SDMC_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '00df4fe2-0025-45ec-814a-36777155e077'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=119','archive': 'https://ecdysis.org/content/dwca/SDSU-TAC_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '87017793-00dc-4f5d-b95b-09e7d17327cc'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=128','archive': 'https://ecdysis.org/content/dwca/MSU-MSUC_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '7ed2ce52-26e5-4847-9563-955ae3e97455'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=106','archive': 'https://ecdysis.org/content/dwca/DCH-DCEC_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = 'abb0a03c-4dcb-4f6f-a31d-55268f63d44c'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=123','archive': 'https://ecdysis.org/content/dwca/USNM-USNMENT_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '879d475f-4b76-4d18-8cf6-a7e5a6d44926'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=100','archive': 'https://ecdysis.org/content/dwca/GMNH-UGCA_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = 'cf42855e-a54a-4488-a79e-beac086ba1d4'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=107','archive': 'https://ecdysis.org/content/dwca/UHIM-UHIM_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '96588aed-3b7a-4179-b92b-2159427f4fcb'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=110','archive': 'https://ecdysis.org/content/dwca/UVM-VTZT_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '4f436daa-01d5-4be6-b5c3-fdd255677536'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=98','archive': 'https://ecdysis.org/content/dwca/VPI-VTEC_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = '34cad268-8226-4280-b637-dde38c82a29e'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=112','archive': 'https://ecdysis.org/content/dwca/WWU-WWUC_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
nuuid = 'b985f284-eac5-4efe-8a7c-c726cdf7cf33'
updatedRecord = {'eml': 'https://ecdysis.org/collections/datasets/emlhandler.php?collid=150','archive': 'https://ecdysis.org/content/dwca/UI-WFBM_DwC-A.zip'}
rssql = "update recordsets set eml_link = '{0}', file_link = '{1}' where uuid = '{2}'".format(updatedRecord['eml'], updatedRecord['archive'], nuuid)
rmsql = "delete from recordsets where file_link = '{0}'".format(updatedRecord['archive'])
db.execute(rmsql)
db.execute(rssql)
db.commit()
