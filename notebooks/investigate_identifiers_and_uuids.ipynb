# %%
import json

import idigbio

from idb.postgres_backend.db import PostgresDB

# %%
api = idigbio.json()

# %%
db = PostgresDB()

# %%
#identifier_fields = {
#    "dwc:Occurrence": [
#        ("idigbio:recordId", lambda r, rs: mungeid(r)),
#        ("idigbio:recordID", lambda r, rs: mungeid(r)),
#        ("dwc:ResourceRelationship", lambda r, rs: idFromRR(r, rs=rs)),
#        ("dwc:occurrenceID", lambda r, rs: rs + "\\" + mungeid(r)),
#        ("id", lambda r, rs: rs + "\\" + mungeid(r)),
#        ("ID", lambda r, rs: rs + "\\" + mungeid(r)),
#    ],
#    ...
    

record_list = api.search_records(rq={"recordset": "3c9420c9-c4a8-47dc-88b7-b5638ca5e716"},
                                 fields=["uuid","occurrenceid","data.id","recordids"])


if record_list is None:
    print("ERROR running query")
else:
    print("itemCount:", record_list['itemCount'])
# Out:
# ('itemCount:', 4692748)

# %%
del(record_list['attribution'])

# %%
# record_list
print(json.dumps(record_list, indent=4))
# Out:
# {
#     "lastModified": "2022-08-14T19:23:49.238Z",
#     "itemCount": 4692748,
#     "items": [
#         {
#             "data": {
#                 "id": "8695457"
#             },
#             "type": "records",
#             "uuid": "78ef6b42-5d2a-49c5-a430-e6d95f5bb248",
#             "indexTerms": {
#                 "recordids": [
#                     "3c9420c9-c4a8-47dc-88b7-b5638ca5e716\\8695457",
#                     "3c9420c9-c4a8-47dc-88b7-b5638ca5e716\\7feb1a99-2fdc-4481-bc16-b4159ef7622d"
#                 ],
#                 "occurrenceid": "7feb1a99-2fdc-4481-bc16-b4159ef7622d",
#                 "uuid": "78ef6b42-5d2a-49c5-a430-e6d95f5bb248"
#             }
#         },
#         {
#             "data": {
#                 "id": "2468067"
#             },
#             "type": "records",
#             "uuid": "cf573715-fdeb-45fe-8bc1-8783adc38848",
#             "indexTerms": {
#                 "recordids": [
# ...

# %%
#db.execute("SELECT count(*) from recordsets")
result = db.fetchone("SELECT count(*) from recordsets")
print(result[0])
# Out:
# 5196

# %% [markdown]
# Here we convert the examples provided by Julie W. into data structure.

# %% [markdown]
# ### Catetory A - iDigBio UUID is missing
#
# > A user imported a specimen record for NHMUK:ZOO:1911.4.3.1 Salamandra salamandra with occurrence ID b6ab040c-a69d-48c0-9096-d29a21fc0b94 and iDigBio UUID 0657795d-5895-4776-b741-d261d93a69bd. This specimen still exists in the NHM data portal and on GBIF, which I'm guessing means the specimen is still present in their IPT? The iDigBio UUID returns a record not found, and I've not been able to find this specimen otherwise by searching iDigBio. The specimens in the first sheet (Bad OID, Bad IDB UUID) of the excel spreadsheet I'm attaching seem to generally fall into this situation.

# %% [markdown]
# ```
# idigbio_uuid	occurrence_id	catalog_number
# c6ad39ec-5c38-4cbf-9450-3fe24a354e53	c5a72921-f72a-484d-a7a3-e9be834c8405	1860.7.22.22
# 9f3d5b12-ce7e-403b-bdbe-e674e926408f	ab9c6a69-9b5e-40dc-ac49-70ad18b30d55	1869.6.20.1
# 0b5dca19-e754-4b7b-9b34-ef9e66b656ae	1b926cbe-f878-456c-a939-956a7d6e6db1	1884.2.29.10
# b21e4387-3b83-4506-b124-d3c8000724df	8f6215b2-c99c-4632-bfaf-8424fd453a5d	1889.12.7.6-7
for line in idigbio_missing_from_spreadsheet.splitlines():
    if len(line) > 0:
        # in the db, the identifers are prefied with recordset_uuid.
        idigbio_uuid = line.split()[0]
        occurrence_id = line.split()[1]
        catalog_number = line.split()[2]
        idigbio_uuids_to_check[idigbio_uuid] = {
            'idigbio_uuid'   : idigbio_uuid,
            'occurrence_id'  : occurrence_id,
            'catalog_number' : catalog_number
        }
print(idigbio_uuids_to_check)
# Out:
# {'dc71ed67-796d-4967-8395-d62f8c354e6d': {'occurrence_id': 'eafd0d08-a134-4c1f-ba10-55ce8d3f64a0', 'catalog_number': '1928.12.20.414-415', 'idigbio_uuid': 'dc71ed67-796d-4967-8395-d62f8c354e6d'}, '7064a7e9-bca6-4fa8-8467-c538c49beb3f': {'occurrence_id': '66648598-0b31-4fed-b9f9-cb8733fd8c84', 'catalog_number': '1957.1.7.49', 'idigbio_uuid': '7064a7e9-bca6-4fa8-8467-c538c49beb3f'}, 'ba6cade7-0039-4f8e-8dc5-d475680cd308': {'occurrence_id': 'c07f5b15-c83d-49ab-9d9a-bf6de35b4308', 'catalog_number': 'pv', 'idigbio_uuid': 'ba6cade7-0039-4f8e-8dc5-d475680cd308'}, '6f4f58c6-2c22-432f-bec3-bca992b841ca': {'occurrence_id': '53c29473-63fd-4a8a-b8d3-d1f81b0116cd', 'catalog_number': '1978.1062', 'idigbio_uuid': '6f4f58c6-2c22-432f-bec3-bca992b841ca'}, 'eadf9c31-8032-4cc0-83ef-349bdb09f449': {'occurrence_id': '95a6da46-a210-4399-b15e-6027ee9d8bac', 'catalog_number': 'PV', 'idigbio_uuid': 'eadf9c31-8032-4cc0-83ef-349bdb09f449'}, 'cdf0193d-95b0-4582-9cd7-0da1338e3bed': {'occurrence_id': 'a7212d7c-8e
# ...

# %% [markdown]
# ### Catetory B - iDigBio UUID pointing to different occurrenceId over time
#
# > A slighty more confusing situation applies for specimens like NHMUK:ZOO:A/1996.11.1 Aegithalos caudatus, which we had a user imported from iDigBio with the occurrence ID e1ba7075-5830-4385-a26a-ca62ef8243eb and iDigBio UUID c9c4cf70-cbcf-4d26-8d9c-d2ffb3e57925. Again, appears on GBIF and the NHM data portal. And the iDigBio UUID resolves to a specimen on iDigBio, but it's a different specimen - NHMUK:ZOO:1979.281, with a different occurrence ID.

# %% [markdown]
# ```
# idigbio_uuid	occurrence_id	catalog_number
# 4b991ae0-6ca8-47b2-96ef-0fa12b96bdc6	948887f1-72a1-4d7b-9d76-7529750db11a	1881.1.17.71
# c9c4cf70-cbcf-4d26-8d9c-d2ffb3e57925	e1ba7075-5830-4385-a26a-ca62ef8243eb	a/1996.11.1
# 9593ca76-1332-4d9b-8b61-52e10e64e708	7a0d526b-764d-45a1-adc0-186b1ed95499	s/2005.22.15
# d1311f6f-c90d-420d-8050-4e56d066c071	9eaab0b0-333a-46c2-916e-98cfaf9a1773	s/1994.7.1
# 2cebeed0-a1a0-4e83-b04c-d3fbf93dd13d	3f8689ed-cf2c-4ba3-9639-9ef17e5f9344	1971.709
# 25c4533d-dd69-44f4-88b4-5589e09ae5a9	f9aaecba-4ef0-43ed-8149-35b474b8d600	1939.12.9.538
# aad33803-144e-419d-840d-0232a8451de7	8f77308a-bb36-4760-af15-0c72a4a13d56	PV R 3803
# ced738fe-0b69-4570-852d-bf2f519c97ac	a0532ccd-ddeb-4678-bd5b-0ae9026ff567	s/1973.1.10
# ```

# %%
idigbio_mismatch_from_spreadsheet = """
idigbio_uuid	occurrence_id	catalog_number
4b991ae0-6ca8-47b2-96ef-0fa12b96bdc6	948887f1-72a1-4d7b-9d76-7529750db11a	1881.1.17.71
c9c4cf70-cbcf-4d26-8d9c-d2ffb3e57925	e1ba7075-5830-4385-a26a-ca62ef8243eb	a/1996.11.1
9593ca76-1332-4d9b-8b61-52e10e64e708	7a0d526b-764d-45a1-adc0-186b1ed95499	s/2005.22.15
d1311f6f-c90d-420d-8050-4e56d066c071	9eaab0b0-333a-46c2-916e-98cfaf9a1773	s/1994.7.1
2cebeed0-a1a0-4e83-b04c-d3fbf93dd13d	3f8689ed-cf2c-4ba3-9639-9ef17e5f9344	1971.709
25c4533d-dd69-44f4-88b4-5589e09ae5a9	f9aaecba-4ef0-43ed-8149-35b474b8d600	1939.12.9.538
aad33803-144e-419d-840d-0232a8451de7	8f77308a-bb36-4760-af15-0c72a4a13d56	PV R 3803
ced738fe-0b69-4570-852d-bf2f519c97ac	a0532ccd-ddeb-4678-bd5b-0ae9026ff567	s/1973.1.10
"""

# %%
mismatch_idigbio_uuids_to_check = {}
for line in idigbio_mismatch_from_spreadsheet.splitlines():
    if len(line) > 0:
        # in the db, the identifers are prefied with recordset_uuid.
        idigbio_uuid = line.split()[0]
        occurrence_id = line.split()[1]
        catalog_number = line.split()[2]
        idigbio_uuids_to_check[idigbio_uuid] = {
            'idigbio_uuid'   : idigbio_uuid,
            'occurrence_id'  : occurrence_id,
            'catalog_number' : catalog_number
        }
print(idigbio_uuids_to_check)
# Out:
# {'dc71ed67-796d-4967-8395-d62f8c354e6d': {'occurrence_id': 'eafd0d08-a134-4c1f-ba10-55ce8d3f64a0', 'catalog_number': '1928.12.20.414-415', 'idigbio_uuid': 'dc71ed67-796d-4967-8395-d62f8c354e6d'}, '7064a7e9-bca6-4fa8-8467-c538c49beb3f': {'occurrence_id': '66648598-0b31-4fed-b9f9-cb8733fd8c84', 'catalog_number': '1957.1.7.49', 'idigbio_uuid': '7064a7e9-bca6-4fa8-8467-c538c49beb3f'}, 'ba6cade7-0039-4f8e-8dc5-d475680cd308': {'occurrence_id': 'c07f5b15-c83d-49ab-9d9a-bf6de35b4308', 'catalog_number': 'pv', 'idigbio_uuid': 'ba6cade7-0039-4f8e-8dc5-d475680cd308'}, '6f4f58c6-2c22-432f-bec3-bca992b841ca': {'occurrence_id': '53c29473-63fd-4a8a-b8d3-d1f81b0116cd', 'catalog_number': '1978.1062', 'idigbio_uuid': '6f4f58c6-2c22-432f-bec3-bca992b841ca'}, 'eadf9c31-8032-4cc0-83ef-349bdb09f449': {'occurrence_id': '95a6da46-a210-4399-b15e-6027ee9d8bac', 'catalog_number': 'PV', 'idigbio_uuid': 'eadf9c31-8032-4cc0-83ef-349bdb09f449'}, 'cdf0193d-95b0-4582-9cd7-0da1338e3bed': {'occurrence_id': 'a7212d7c-8e
# ...
